# %% [markdown]
# ## Telecom - project objective:
#
#  - Learn to predict customer churn for the telecommunications operator "Niyeдиногоразрыва.com".
#
#  - If it turns out that a user is planning to leave, offer them promo codes and special conditions.

# %% [markdown]
# ### Description of services
#
# <b>The operator provides two main types of services:</b>
#
# 1. Fixed-line telephone communication. It is possible to connect a telephone set to multiple lines simultaneously.
# 2. Internet. Connection can be of two types: through a telephone line (DSL, which stands for "digital subscriber line") or fiber optic cable (Fiber optic).
#
# <b>In addition, the following services are also available:</b>
#
# - Internet security: antivirus (DeviceProtection) and blocking of unsafe websites (OnlineSecurity);
# - Dedicated technical support line (TechSupport);
# - Cloud storage for data backup (OnlineBackup);
# - Streaming TV (StreamingTV) and movie catalog (StreamingMovies).
#
# <b>Customers can pay for services each month or sign a contract for 1-2 years. Various payment methods are available.</b>

# %% [markdown]
# The data consists of files obtained from different sources:
#
# - `contract.csv` — contract information;
# - `personal.csv` — customer personal data;
# - `internet.csv` —  information about internet services;
# - `phone.csv` — information about telephone services.
#
# In all files, the `customerID` column contains the customer code.
#
# The contract information is valid as of <b>February 1, 2020.</b>

# %% [markdown]
# ### Exploring the general data.

# %%
# !pip install phik
# !pip install category_encoders
# !pip install -U scikit-learn
# Out:
# Collecting phik
#   Downloading phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\natal\anaconda3\lib\site-packages (from phik) (1.5.1)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\natal\anaconda3\lib\site-packages (from phik) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\natal\anaconda3\lib\site-packages (from phik) (3.5.1)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\natal\anaconda3\lib\site-packages (from phik) (1.7.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\natal\anaconda3\lib\site-packages (from phik) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\natal\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natal\anaconda3\lib\site-packages (from pandas>=0.25.1->phik) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\natal\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Installing collected packages: phik
# Successfully installed phik-0.12.3
# Collecting category_encoders
#   Downloading category_encoders-2.6.0-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (0.13.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (1.7.3)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (1.5.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (1.21.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\natal\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\natal\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\natal\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2021.3)
# Requirement already satisfied: six in c:\users\natal\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\natal\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\natal\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\natal\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\natal\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->category_encoders) (3.0.4)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.6.0
# Requirement already satisfied: scikit-learn in c:\users\natal\anaconda3\lib\site-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\natal\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\natal\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\natal\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Installing collected packages: joblib, scikit-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

from phik import resources, report
from phik.binning import bin_data

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, make_scorer

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline


import warnings
warnings.filterwarnings('ignore')

# %%
try:
    telecom_contact = pd.read_csv(r"C:\Users\natal\OneDrive\Рабочий стол\telecom\final_provider\contract.csv")
    telecom_internet = pd.read_csv(r"C:\Users\natal\OneDrive\Рабочий стол\telecom\final_provider\internet.csv")
    telecom_personal = pd.read_csv(r"C:\Users\natal\OneDrive\Рабочий стол\telecom\final_provider\personal.csv")
    telecom_phone = pd.read_csv(r"C:\Users\natal\OneDrive\Рабочий стол\telecom\final_provider\phone.csv")

except:
    telecom_contact = pd.read_csv("/datasets/final_provider/contract.csv")
    telecom_internet = pd.read_csv("/datasets/final_provider/internet.csv")
    telecom_personal = pd.read_csv("/datasets/final_provider/personal.csv")
    telecom_phone = pd.read_csv("/datasets/final_provider/phone.csv")

# %%
telecom_contact.head(10)
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# 5  9305-CDSKC  2019-03-01  2019-11-01 00:00:00  Month-to-month
# 6  1452-KIOVK  2018-04-01                   No  Month-to-month
# 7  6713-OKOMC  2019-04-01                   No  Month-to-month
# 8  7892-POOKP  2017-07-01  2019-11-01 00:00:00  Month-to-month
# 9  6388-TABGU  2014-12-01                   No        One year
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
# 5              Yes           Electronic check           99.65        820.5
# 6              Yes    Credit card (automatic)           89.10       1949.4
# 7               No               Mailed check           29.75        301.9
# 8              Yes           Electronic check          104.80      3046.05
# 9               No  Bank transfer (automatic)           56.15      3487.95

# %%
telecom_contact.sample(10)
# Out:
#       customerID   BeginDate              EndDate            Type  \
# 5685  4475-NVTLU  2016-05-01                   No        Two year
# 6594  8317-BVKSO  2018-12-01                   No  Month-to-month
# 6810  7758-XKCBS  2018-08-01  2019-11-01 00:00:00  Month-to-month
# 1355  5624-RYAMH  2019-05-01                   No  Month-to-month
# 5516  6923-EFPNL  2019-08-01  2019-12-01 00:00:00  Month-to-month
# 3283  1085-LDWAM  2014-05-01                   No        One year
# 2825  7610-TVOPG  2018-11-01                   No  Month-to-month
# 4755  8849-AYPTR  2017-05-01                   No  Month-to-month
# 1689  0274-JKUJR  2019-07-01                   No  Month-to-month
# 4690  7036-ZZKBD  2017-07-01                   No  Month-to-month
#
#      PaperlessBilling            PaymentMethod  MonthlyCharges TotalCharges
# 5685               No         Electronic check           19.20        903.7
# 6594              Yes         Electronic check           20.05        299.3
# 6810              Yes         Electronic check           29.70       438.25
# 1355              Yes         Electronic check           19.50       178.85
# 5516               No  Credit card (automatic)           51.75        201.1
# 3283              Yes  Credit card (automatic)           20.35      1442.65
# 2825              Yes         Electronic check           26.35        378.6
# 4755               No         Electronic check           91.25      2964.05
# 1689               No             Mailed check           58.85        465.7
# 4690              Yes  Credit card (automatic)           66.40       2019.8

# %%
telecom_contact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB

# %% [markdown]
# <b>!TotalCharges      7043 non-null   object </b>

# %%
telecom_contact.describe()
# Out:
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %%
telecom_contact.duplicated().sum()
# Out:
# 0

# %%
telecom_contact.notnull().sum()
# Out:
# customerID          7043
# BeginDate           7043
# EndDate             7043
# Type                7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7043
# dtype: int64

# %%
telecom_internet.head(10)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
# 5  9305-CDSKC     Fiber optic             No           No              Yes
# 6  1452-KIOVK     Fiber optic             No          Yes               No
# 7  6713-OKOMC             DSL            Yes           No               No
# 8  7892-POOKP     Fiber optic             No           No              Yes
# 9  6388-TABGU             DSL            Yes          Yes               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No
# 5          No         Yes             Yes
# 6          No         Yes              No
# 7          No          No              No
# 8         Yes         Yes             Yes
# 9          No          No              No

# %%
telecom_internet.sample(10)
# Out:
#       customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 839   7013-PSXHK             DSL             No           No              Yes
# 1286  2929-QNSRW     Fiber optic             No          Yes               No
# 43    2954-PIBKO             DSL            Yes           No              Yes
# 2216  3999-QGRJH     Fiber optic             No           No               No
# 926   0135-NMXAP     Fiber optic             No          Yes               No
# 4995  2101-RANCD     Fiber optic             No           No               No
# 5421  6502-MJQAE     Fiber optic             No           No               No
# 1868  6650-BWFRT     Fiber optic            Yes          Yes              Yes
# 1195  5724-BIDBU             DSL            Yes           No               No
# 4667  0239-OXEXL     Fiber optic            Yes          Yes               No
#
#      TechSupport StreamingTV StreamingMovies
# 839          Yes         Yes             Yes
# 1286          No         Yes             Yes
# 43           Yes          No              No
# 2216          No          No              No
# 926           No         Yes              No
# 4995          No          No              No
# 5421          No          No              No
# 1868         Yes         Yes             Yes
# 1195          No          No              No
# 4667          No          No              No

# %%
telecom_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %%
telecom_internet.describe()
# Out:
#         customerID InternetService OnlineSecurity OnlineBackup  \
# count         5517            5517           5517         5517
# unique        5517               2              2            2
# top     7590-VHVEG     Fiber optic             No           No
# freq             1            3096           3498         3088
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies
# count              5517        5517        5517            5517
# unique                2           2           2               2
# top                  No          No          No              No
# freq               3095        3473        2810            2785

# %%
telecom_internet.duplicated().sum()
# Out:
# 0

# %%
telecom_internet.notnull().sum()
# Out:
# customerID          5517
# InternetService     5517
# OnlineSecurity      5517
# OnlineBackup        5517
# DeviceProtection    5517
# TechSupport         5517
# StreamingTV         5517
# StreamingMovies     5517
# dtype: int64

# %%
telecom_personal.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# 5  9305-CDSKC  Female              0      No         No
# 6  1452-KIOVK    Male              0      No        Yes
# 7  6713-OKOMC  Female              0      No         No
# 8  7892-POOKP  Female              0     Yes         No
# 9  6388-TABGU    Male              0      No        Yes

# %%
telecom_personal.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 117   5299-RULOA  Female              0     Yes        Yes
# 5407  9786-YWNHU  Female              0     Yes        Yes
# 254   3675-YDUPJ    Male              0      No         No
# 1680  5451-MHQOF    Male              0     Yes        Yes
# 1619  5930-GBIWP    Male              0      No         No
# 5886  1709-EJDOX  Female              0     Yes        Yes
# 1898  6689-TCZHQ  Female              1      No         No
# 6827  1036-GUDCL    Male              0     Yes        Yes
# 1348  1184-PJVDB    Male              0     Yes         No
# 1033  2632-TACXW  Female              0     Yes         No

# %%
telecom_personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
telecom_personal.describe()
# Out:
#        SeniorCitizen
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
telecom_personal.duplicated().sum()
# Out:
# 0

# %%
telecom_personal.notnull().sum()
# Out:
# customerID       7043
# gender           7043
# SeniorCitizen    7043
# Partner          7043
# Dependents       7043
# dtype: int64

# %%
telecom_phone.head(10)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# 5  7892-POOKP           Yes
# 6  6388-TABGU            No
# 7  9763-GRSKD            No
# 8  7469-LKBCI            No
# 9  8091-TTVAX           Yes

# %%
telecom_phone.sample(10)
# Out:
#       customerID MultipleLines
# 2190  5136-KCKGI           Yes
# 4474  6075-QMNRR            No
# 2122  6463-HHXJR           Yes
# 3659  5863-OOKCL            No
# 1794  3723-BFBGR           Yes
# 3599  7225-CBZPL           Yes
# 5354  8277-RVRSV           Yes
# 6141  1047-RNXZV            No
# 2377  2262-SLNVK            No
# 5444  9503-XJUME            No

# %%
telecom_phone.describe()
# Out:
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390

# %%
telecom_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %%
telecom_phone.duplicated().sum()
# Out:
# 0

# %%
telecom_phone.notnull().sum()
# Out:
# customerID       6361
# MultipleLines    6361
# dtype: int64

# %% [markdown]
# <b>Summary:</b> At first glance, the TotalCharges column in the telecom_contract table has an object data type, which may indicate that it contains non-numeric values that need to be converted to numeric values. The time format in the BeginDate and EndDate columns should also be changed. It can also be said that the number of rows in the tables differs.

# %% [markdown]
# ### Data preparation

# %%
#Let's merge the tables.
telecom_contact = telecom_contact.set_index('customerID')
telecom_internet = telecom_internet.set_index('customerID')
telecom_personal = telecom_personal.set_index('customerID')
telecom_phone = telecom_phone.set_index('customerID')

# %%
telecom = telecom_contact.join([telecom_internet, telecom_personal, telecom_phone])
telecom.sample(20)
# Out:
#              BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 6869-FGJJC  2014-06-01                   No        One year               No
# 2091-RFFBA  2017-06-01  2020-01-01 00:00:00  Month-to-month              Yes
# 1813-JLKWR  2014-10-01                   No        One year               No
# 1074-AMIOH  2015-09-01                   No  Month-to-month              Yes
# 2346-CZYIL  2017-11-01                   No        Two year               No
# 8096-LOIST  2018-07-01                   No  Month-to-month              Yes
# 9848-JQJTX  2014-02-01                   No        Two year              Yes
# 0177-PXBAT  2017-05-01                   No  Month-to-month              Yes
# 6137-MFAJN  2016-02-01                   No  Month-to-month              Yes
# 7396-VJUZB  2019-10-01                   No  Month-to-month               No
# 4248-QPAVC  2018-06-01  2019-11-01 00:00:00  Month-to-month              Yes
# 2839-RFSQE  2019-11-01  2020-01-01 00:00:00  Month-to-month               No
# 5424-RLQLC  2019-04-01                   No  Month-to-month              Yes
# 7901-HXJVA  2018-12-01                   No  Month-to-month               No
# 1448-PWKYE  2019-12-01  2020-01-01 00:00:00  Month-to-month               No
# 3771-PZOBW  2018-06-01                   No  Month-to-month              Yes
# 6283-GITPX  2014-03-01                   No        Two year              Yes
# 2799-TSLAG  2014-09-01                   No        Two year              Yes
# 1518-VOWAV  2019-04-01  2020-01-01 00:00:00  Month-to-month              Yes
# 7271-AJDTL  2015-07-01                   No  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges  \
# customerID
# 6869-FGJJC    Credit card (automatic)           79.60      5461.45
# 2091-RFFBA           Electronic check           73.90      2217.15
# 1813-JLKWR  Bank transfer (automatic)           19.80      1336.65
# 1074-AMIOH  Bank transfer (automatic)          108.25       5935.1
# 2346-CZYIL    Credit card (automatic)           20.35        531.6
# 8096-LOIST           Electronic check           56.20       1093.4
# 9848-JQJTX  Bank transfer (automatic)          100.90      7459.05
# 0177-PXBAT  Bank transfer (automatic)          109.90       3694.7
# 6137-MFAJN           Electronic check           44.80      2104.55
# 7396-VJUZB               Mailed check           45.25       155.35
# 4248-QPAVC  Bank transfer (automatic)           85.35      1463.45
# 2839-RFSQE               Mailed check           20.65         38.7
# 5424-RLQLC               Mailed check           59.65       638.95
# 7901-HXJVA           Electronic check           76.45      1117.55
# 1448-PWKYE           Electronic check           80.00           80
# 3771-PZOBW    Credit card (automatic)           90.70      1781.35
# 6283-GITPX    Credit card (automatic)           76.90       5522.7
# 2799-TSLAG  Bank transfer (automatic)           25.30      1748.55
# 1518-VOWAV           Electronic check           74.65       703.55
# 7271-AJDTL    Credit card (automatic)           94.45       5073.1
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 6869-FGJJC     Fiber optic             No          Yes              Yes
# 2091-RFFBA     Fiber optic             No           No               No
# 1813-JLKWR             NaN            NaN          NaN              NaN
# 1074-AMIOH     Fiber optic             No          Yes              Yes
# 2346-CZYIL             NaN            NaN          NaN              NaN
# 8096-LOIST             DSL             No           No               No
# 9848-JQJTX     Fiber optic             No          Yes              Yes
# 0177-PXBAT     Fiber optic            Yes           No              Yes
# 6137-MFAJN             DSL            Yes          Yes               No
# 7396-VJUZB             DSL             No           No               No
# 4248-QPAVC     Fiber optic            Yes           No              Yes
# 2839-RFSQE             NaN            NaN          NaN              NaN
# 5424-RLQLC             DSL             No          Yes               No
# 7901-HXJVA     Fiber optic             No           No              Yes
# 1448-PWKYE     Fiber optic             No           No               No
# 3771-PZOBW     Fiber optic             No           No              Yes
# 6283-GITPX             DSL            Yes          Yes              Yes
# 2799-TSLAG             NaN            NaN          NaN              NaN
# 1518-VOWAV             DSL            Yes          Yes               No
# 7271-AJDTL     Fiber optic             No          Yes              Yes
#
#            TechSupport StreamingTV StreamingMovies  gender  SeniorCitizen  \
# customerID
# 6869-FGJJC          No          No              No    Male              0
# 2091-RFFBA          No          No              No  Female              1
# 1813-JLKWR         NaN         NaN             NaN  Female              0
# 1074-AMIOH         Yes         Yes             Yes  Female              0
# 2346-CZYIL         NaN         NaN             NaN    Male              0
# 8096-LOIST          No          No             Yes  Female              0
# 9848-JQJTX          No         Yes             Yes    Male              0
# 0177-PXBAT         Yes         Yes             Yes    Male              1
# 6137-MFAJN          No         Yes              No  Female              0
# 7396-VJUZB          No          No              No    Male              0
# 4248-QPAVC          No          No              No  Female              1
# 2839-RFSQE         NaN         NaN             NaN  Female              0
# 5424-RLQLC          No         Yes              No    Male              0
# 7901-HXJVA          No          No              No    Male              0
# 1448-PWKYE          No          No             Yes    Male              0
# 3771-PZOBW          No         Yes              No    Male              0
# 6283-GITPX         Yes         Yes              No    Male              0
# 2799-TSLAG         NaN         NaN             NaN  Female              0
# 1518-VOWAV          No         Yes             Yes  Female              0
# 7271-AJDTL          No         Yes              No  Female              0
#
#            Partner Dependents MultipleLines
# customerID
# 6869-FGJJC      No         No            No
# 2091-RFFBA      No         No           Yes
# 1813-JLKWR     Yes        Yes            No
# 1074-AMIOH     Yes        Yes            No
# 2346-CZYIL      No         No            No
# 8096-LOIST      No         No            No
# 9848-JQJTX      No         No           Yes
# 0177-PXBAT     Yes         No           Yes
# 6137-MFAJN      No         No           NaN
# 7396-VJUZB     Yes        Yes            No
# 4248-QPAVC     Yes         No           Yes
# 2839-RFSQE      No         No            No
# 5424-RLQLC      No         No            No
# 7901-HXJVA      No         No            No
# 1448-PWKYE     Yes        Yes            No
# 3771-PZOBW      No         No           Yes
# 6283-GITPX      No        Yes            No
# 2799-TSLAG     Yes        Yes           Yes
# 1518-VOWAV      No         No            No
# 7271-AJDTL     Yes         No           Yes

# %%
telecom.describe()
# Out:
#        MonthlyCharges  SeniorCitizen
# count     7043.000000    7043.000000
# mean        64.761692       0.162147
# std         30.090047       0.368612
# min         18.250000       0.000000
# 25%         35.500000       0.000000
# 50%         70.350000       0.000000
# 75%         89.850000       0.000000
# max        118.750000       1.000000

# %%
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   object
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   InternetService   5517 non-null   object
#  8   OnlineSecurity    5517 non-null   object
#  9   OnlineBackup      5517 non-null   object
#  10  DeviceProtection  5517 non-null   object
#  11  TechSupport       5517 non-null   object
#  12  StreamingTV       5517 non-null   object
#  13  StreamingMovies   5517 non-null   object
#  14  gender            7043 non-null   object
#  15  SeniorCitizen     7043 non-null   int64
#  16  Partner           7043 non-null   object
#  17  Dependents        7043 non-null   object
#  18  MultipleLines     6361 non-null   object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 1.1+ MB

# %%
telecom.duplicated().sum()
# Out:
# 13

# %%
telecom.isnull().sum()
# Out:
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# MultipleLines        682
# dtype: int64

# %% [markdown]
# <b>After merging the tables, we have missing values and duplicates.</b>

# %% [markdown]
# telecom_contact['TotalCharges'] = telecom_contact['TotalCharges'].astype('float64')
#
# ValueError: could not convert string to float: ''

# %%
telecom['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# Name: InternetService, dtype: int64

# %%
#If a customer did not provide information about the internet service, it may be because they are not using this service. Therefore, we can replace the missing values with 'No'.
telecom['InternetService'] = telecom['InternetService'].fillna('No')

# %%
telecom.columns
# Out:
# Index(['BeginDate', 'EndDate', 'Type', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'MultipleLines'],
#       dtype='object')

# %% [markdown]
# Most likely, the missing values in these columns may indicate that the services were not connected. Therefore, to fill in the missing values, it was decided to replace them with the string 'No'.

# %%
new  = ['OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies',
       'MultipleLines']
telecom[new] = telecom[new].fillna('No')

# %%
#will convert the time to the format we need.
telecom['BeginDate'] = pd.to_datetime(telecom['BeginDate'], format='%Y-%m-%d')

# %%
telecom['EndDate'].value_counts()
# Out:
# No                     5174
# 2019-11-01 00:00:00     485
# 2019-12-01 00:00:00     466
# 2020-01-01 00:00:00     460
# 2019-10-01 00:00:00     458
# Name: EndDate, dtype: int64

# %%
def client_left(EndDate):
    if EndDate == 'No':
        return 'No'
    if EndDate != 'No':
        return 'Yes'
telecom['ClientLeft'] = telecom['EndDate'].apply(client_left)

# %%
telecom[telecom['TotalCharges'] == ' ']
# Out:
#             BeginDate EndDate      Type PaperlessBilling  \
# customerID
# 4472-LVYGI 2020-02-01      No  Two year              Yes
# 3115-CZMZD 2020-02-01      No  Two year               No
# 5709-LVOEQ 2020-02-01      No  Two year               No
# 4367-NUYAO 2020-02-01      No  Two year               No
# 1371-DWPAZ 2020-02-01      No  Two year               No
# 7644-OMVMY 2020-02-01      No  Two year               No
# 3213-VVOLG 2020-02-01      No  Two year               No
# 2520-SGTTA 2020-02-01      No  Two year               No
# 2923-ARZLG 2020-02-01      No  One year              Yes
# 4075-WKNIU 2020-02-01      No  Two year               No
# 2775-SEFEE 2020-02-01      No  Two year              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges  \
# customerID
# 4472-LVYGI  Bank transfer (automatic)           52.55
# 3115-CZMZD               Mailed check           20.25
# 5709-LVOEQ               Mailed check           80.85
# 4367-NUYAO               Mailed check           25.75
# 1371-DWPAZ    Credit card (automatic)           56.05
# 7644-OMVMY               Mailed check           19.85
# 3213-VVOLG               Mailed check           25.35
# 2520-SGTTA               Mailed check           20.00
# 2923-ARZLG               Mailed check           19.70
# 4075-WKNIU               Mailed check           73.35
# 2775-SEFEE  Bank transfer (automatic)           61.90
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 4472-LVYGI             DSL            Yes           No              Yes
# 3115-CZMZD              No             No           No               No
# 5709-LVOEQ             DSL            Yes          Yes              Yes
# 4367-NUYAO              No             No           No               No
# 1371-DWPAZ             DSL            Yes          Yes              Yes
# 7644-OMVMY              No             No           No               No
# 3213-VVOLG              No             No           No               No
# 2520-SGTTA              No             No           No               No
# 2923-ARZLG              No             No           No               No
# 4075-WKNIU             DSL             No          Yes              Yes
# 2775-SEFEE             DSL            Yes          Yes               No
#
#            TechSupport StreamingTV StreamingMovies  gender  SeniorCitizen  \
# customerID
# 4472-LVYGI         Yes         Yes              No  Female              0
# 3115-CZMZD          No          No              No    Male              0
# 5709-LVOEQ          No         Yes             Yes  Female              0
# 4367-NUYAO          No          No              No    Male              0
# 1371-DWPAZ         Yes         Yes              No  Female              0
# 7644-OMVMY          No          No              No    Male              0
# 3213-VVOLG          No          No              No    Male              0
# 2520-SGTTA          No          No              No  Female              0
# 2923-ARZLG          No          No              No    Male              0
# 4075-WKNIU         Yes         Yes              No  Female              0
# 2775-SEFEE         Yes          No              No    Male              0
#
#            Partner Dependents MultipleLines ClientLeft
# customerID
# 4472-LVYGI     Yes        Yes            No         No
# 3115-CZMZD      No        Yes            No         No
# 5709-LVOEQ     Yes        Yes            No         No
# 4367-NUYAO     Yes        Yes           Yes         No
# 1371-DWPAZ     Yes        Yes            No         No
# 7644-OMVMY     Yes        Yes            No         No
# 3213-VVOLG     Yes        Yes           Yes         No
# 2520-SGTTA     Yes        Yes            No         No
# 2923-ARZLG     Yes        Yes            No         No
# 4075-WKNIU     Yes        Yes           Yes         No
# 2775-SEFEE      No        Yes           Yes         No

# %%
#We can see that all date values are the same (2020-02-01), so we can drop them as they don't provide any useful information.
telecom['TotalCharges'] = telecom['TotalCharges'].replace(" ", 0).astype('float32')

# %%
#will add a new column "HasEndDate"
telecom['HasEndDate'] = (telecom['EndDate'] != 'No')
telecom['HasEndDate']
# Out:
# customerID
# 7590-VHVEG    False
# 5575-GNVDE    False
# 3668-QPYBK     True
# 7795-CFOCW    False
# 9237-HQITU     True
#               ...
# 6840-RESVB    False
# 2234-XADUH    False
# 4801-JZAZL    False
# 8361-LTMKD     True
# 3186-AJIEK    False
# Name: HasEndDate, Length: 7043, dtype: bool

# %% [markdown]
# As the information is up to date as of February 1, 2020, let's replace all No values in EndDate with this date. We will use these derived columns for data analysis.

# %%
telecom['EndDate'] = telecom['EndDate'].replace('No', '2020-02-01 00:00:00')
telecom['EndDate'] = pd.to_datetime(telecom['EndDate'], format='%Y-%m-%d')

# %%
telecom['BeginMonth'] = pd.DatetimeIndex(telecom['BeginDate']).month

telecom['BeginYear'] = pd.DatetimeIndex(telecom['BeginDate']).year

telecom['UsingDays'] = (pd.to_datetime(telecom['EndDate']) - pd.to_datetime(telecom['BeginDate'])).dt.days

# %%
telecom = telecom.rename(columns={'gender':'Gender'})

# %%
telecom.sample(10)
# Out:
#             BeginDate    EndDate            Type PaperlessBilling  \
# customerID
# 5649-VUKMC 2018-12-01 2019-12-01        One year               No
# 6732-FZUGP 2016-03-01 2020-02-01        One year               No
# 5572-ZDXHY 2018-02-01 2019-12-01  Month-to-month              Yes
# 5325-UWTWJ 2017-07-01 2020-02-01  Month-to-month              Yes
# 9921-QFQUL 2018-03-01 2020-02-01  Month-to-month               No
# 9565-DJPIB 2019-06-01 2019-10-01  Month-to-month               No
# 9603-OAIHC 2020-01-01 2020-02-01  Month-to-month              Yes
# 4566-NECEV 2019-09-01 2020-02-01  Month-to-month               No
# 8314-DPQHL 2019-05-01 2020-02-01        One year               No
# 6168-WFVVF 2019-10-01 2020-01-01  Month-to-month              Yes
#
#                       PaymentMethod  MonthlyCharges  TotalCharges  \
# customerID
# 5649-VUKMC             Mailed check           95.50   1115.150024
# 6732-FZUGP  Credit card (automatic)           94.90   4615.250000
# 5572-ZDXHY             Mailed check           84.30   1855.650024
# 5325-UWTWJ  Credit card (automatic)           90.55   2929.750000
# 9921-QFQUL             Mailed check           90.15   2044.949951
# 9565-DJPIB             Mailed check           89.60    365.649994
# 9603-OAIHC         Electronic check           70.05     70.050003
# 4566-NECEV         Electronic check           96.55    500.100006
# 8314-DPQHL             Mailed check           50.80    463.600006
# 6168-WFVVF         Electronic check           70.30    235.500000
#
#            InternetService OnlineSecurity OnlineBackup  ...  Gender  \
# customerID                                              ...
# 5649-VUKMC     Fiber optic             No           No  ...  Female
# 6732-FZUGP     Fiber optic            Yes           No  ...  Female
# 5572-ZDXHY     Fiber optic             No          Yes  ...  Female
# 5325-UWTWJ     Fiber optic            Yes          Yes  ...    Male
# 9921-QFQUL     Fiber optic             No           No  ...  Female
# 9565-DJPIB     Fiber optic             No          Yes  ...  Female
# 9603-OAIHC     Fiber optic             No           No  ...    Male
# 4566-NECEV     Fiber optic             No          Yes  ...    Male
# 8314-DPQHL             DSL            Yes           No  ...    Male
# 6168-WFVVF     Fiber optic             No           No  ...  Female
#
#            SeniorCitizen Partner Dependents MultipleLines  ClientLeft  \
# customerID
# 5649-VUKMC             0      No         No            No         Yes
# 6732-FZUGP             0      No         No           Yes          No
# 5572-ZDXHY             0      No         No            No         Yes
# 5325-UWTWJ             0     Yes         No           Yes          No
# 9921-QFQUL             0     Yes         No           Yes          No
# 9565-DJPIB             0      No        Yes           Yes         Yes
# 9603-OAIHC             1      No         No            No          No
# 4566-NECEV             0      No         No           Yes          No
# 8314-DPQHL             0      No         No            No          No
# 6168-WFVVF             1      No         No            No         Yes
#
#            HasEndDate BeginMonth BeginYear UsingDays
# customerID
# 5649-VUKMC       True         12      2018       365
# 6732-FZUGP      False          3      2016      1432
# 5572-ZDXHY       True          2      2018       668
# 5325-UWTWJ      False          7      2017       945
# 9921-QFQUL      False          3      2018       702
# 9565-DJPIB       True          6      2019       122
# 9603-OAIHC      False          1      2020        31
# 4566-NECEV      False          9      2019       153
# 8314-DPQHL      False          5      2019       276
# 6168-WFVVF       True         10      2019        92
#
# [10 rows x 24 columns]

# %%
#Delete BeginDate и EndDate
telecom = telecom.drop(['BeginDate','EndDate'], axis=1)
telecom.sample(5)
# Out:
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 6862-CQUMB  Month-to-month              Yes    Credit card (automatic)
# 0486-LGCCH        Two year               No               Mailed check
# 6919-ELBGL        Two year              Yes  Bank transfer (automatic)
# 0380-ZCSBI  Month-to-month               No    Credit card (automatic)
# 3567-PQTSO        One year              Yes           Electronic check
#
#             MonthlyCharges  TotalCharges InternetService OnlineSecurity  \
# customerID
# 6862-CQUMB           96.10   3646.800049     Fiber optic             No
# 0486-LGCCH           19.65    225.750000              No             No
# 6919-ELBGL          114.95   8196.400391     Fiber optic            Yes
# 0380-ZCSBI           20.00    198.699997              No             No
# 3567-PQTSO          105.25   5576.299805     Fiber optic             No
#
#            OnlineBackup DeviceProtection TechSupport  ... Gender  \
# customerID                                            ...
# 6862-CQUMB          Yes               No          No  ...   Male
# 0486-LGCCH           No               No          No  ...   Male
# 6919-ELBGL          Yes              Yes         Yes  ...   Male
# 0380-ZCSBI           No               No          No  ...   Male
# 3567-PQTSO          Yes              Yes          No  ...   Male
#
#            SeniorCitizen Partner  Dependents MultipleLines ClientLeft  \
# customerID
# 6862-CQUMB             0      No          No            No         No
# 0486-LGCCH             0     Yes         Yes            No         No
# 6919-ELBGL             1     Yes         Yes           Yes         No
# 0380-ZCSBI             0      No          No            No         No
# 3567-PQTSO             0     Yes         Yes           Yes         No
#
#            HasEndDate BeginMonth  BeginYear  UsingDays
# customerID
# 6862-CQUMB      False          1       2017       1126
# 0486-LGCCH      False          3       2019        337
# 6919-ELBGL      False          2       2014       2191
# 0380-ZCSBI      False          4       2019        306
# 3567-PQTSO      False          9       2015       1614
#
# [5 rows x 22 columns]

# %%
telecom.isnull().sum()
# Out:
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# MultipleLines       0
# ClientLeft          0
# HasEndDate          0
# BeginMonth          0
# BeginYear           0
# UsingDays           0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Matthews correlation coefficient (MCC)
correlations = telecom.phik_matrix()

sns.set(font_scale=1.2)
plt.figure(figsize=(20,20))
sns.heatmap(correlations, annot=True, fmt='.2f', cmap='RdYlGn')
plt.title('Matthews correlation coefficient (MCC) of telecommunications data')
plt.show()
# Out:
# interval columns not set, guessing: ['MonthlyCharges', 'TotalCharges', 'SeniorCitizen', 'BeginMonth', 'BeginYear', 'UsingDays']

# %% [markdown]
# <b>
# The strongest positive correlation (0.933) is observed between Type and BeginYear, which may indicate a certain pattern in the dynamics of these variables.
#
# Another strong positive correlation (0.850) is observed between TotalCharges and ClientLeft/HasEndDate, which may suggest that customers with high total charges are more likely to terminate their contract.
#
# There are strong positive correlations between different internet and streaming services, which is expected as users are likely to choose multiple services.
#
# There is a weak positive correlation between PaperlessBilling and Type, which may mean that users who signed up for a certain type of contract are more likely to opt out of paper bills.
#
# There is a strong negative correlation (-0.678) between ClientLeft and HasEndDate, which may be related to the fact that customers who have not yet completed their contract are unlikely to terminate it.
#
# Some variables have zero correlation with each other (for example, Gender and OnlineSecurity), which may indicate the absence of a relationship between these variables.
#
# There is a strong positive correlation between OnlineSecurity and OnlineBackup, as well as between DeviceProtection and StreamingMovies/StreamingTV, which may indicate that customers using certain services may be inclined to use other services.
#
# There is a strong positive correlation between Partner and Dependents, which means that customers who have a partner are likely to have dependents.</b>

# %%
corr_matrix = telecom.corr()
corr_table = corr_matrix.style.background_gradient('RdYlGn')
corr_table.set_caption('Telecom Data Correlation Matrix')
display(corr_table)
# Out:
# <style type="text/css">
# #T_bb90c_row0_col0, #T_bb90c_row1_col1, #T_bb90c_row2_col2, #T_bb90c_row3_col3, #T_bb90c_row4_col4, #T_bb90c_row5_col5, #T_bb90c_row6_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bb90c_row0_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_bb90c_row0_col2 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_bb90c_row0_col3, #T_bb90c_row6_col0 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_bb90c_row0_col4, #T_bb90c_row3_col2 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_bb90c_row0_col5 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_bb90c_row0_col6 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_bb90c_row1_col0 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_bb90c_row1_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_bb90c_row1_col3 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_bb90c_row1_col4 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_bb90c_row1_col5 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_bb90c_row1_col6 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_bb90c_row2_col0 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_bb90c_row2_col1, #T_bb90c_row2_col6 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_bb90c_row2_col3 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_bb90c_row2_col4 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_bb90c_row2_col5 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_bb90c_row3_col0 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_bb90c_row3_col1, #T_bb90c_row4_col1 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_bb90c_row3_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_bb90c_row3_col5 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_bb90c_row3_col6 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_bb90c_row4_col0 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_bb90c_row4_col2 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_bb90c_row4_col3 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_bb90c_row4_col5 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_bb90c_row4_col6 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_bb90c_row5_col0, #T_bb90c_row5_col1, #T_bb90c_row5_col2, #T_bb90c_row5_col6, #T_bb90c_row6_col3, #T_bb90c_row6_col4, #T_bb90c_row6_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bb90c_row5_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_bb90c_row5_col4 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_bb90c_row6_col1 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_bb90c_row6_col2 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb90c">
#   <caption>Telecom Data Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb90c_level0_col0" class="col_heading level0 col0" >MonthlyCharges</th>
#       <th id="T_bb90c_level0_col1" class="col_heading level0 col1" >TotalCharges</th>
#       <th id="T_bb90c_level0_col2" class="col_heading level0 col2" >SeniorCitizen</th>
#       <th id="T_bb90c_level0_col3" class="col_heading level0 col3" >HasEndDate</th>
#       <th id="T_bb90c_level0_col4" class="col_heading level0 col4" >BeginMonth</th>
#       <th id="T_bb90c_level0_col5" class="col_heading level0 col5" >BeginYear</th>
#       <th id="T_bb90c_level0_col6" class="col_heading level0 col6" >UsingDays</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb90c_level0_row0" class="row_heading level0 row0" >MonthlyCharges</th>
#       <td id="T_bb90c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bb90c_row0_col1" class="data row0 col1" >0.651174</td>
#       <td id="T_bb90c_row0_col2" class="data row0 col2" >0.220173</td>
#       <td id="T_bb90c_row0_col3" class="data row0 col3" >0.193356</td>
#       <td id="T_bb90c_row0_col4" class="data row0 col4" >-0.018072</td>
#       <td id="T_bb90c_row0_col5" class="data row0 col5" >-0.264251</td>
#       <td id="T_bb90c_row0_col6" class="data row0 col6" >0.247754</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row1" class="row_heading level0 row1" >TotalCharges</th>
#       <td id="T_bb90c_row1_col0" class="data row1 col0" >0.651174</td>
#       <td id="T_bb90c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bb90c_row1_col2" class="data row1 col2" >0.103006</td>
#       <td id="T_bb90c_row1_col3" class="data row1 col3" >-0.198324</td>
#       <td id="T_bb90c_row1_col4" class="data row1 col4" >-0.194289</td>
#       <td id="T_bb90c_row1_col5" class="data row1 col5" >-0.819539</td>
#       <td id="T_bb90c_row1_col6" class="data row1 col6" >0.826109</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row2" class="row_heading level0 row2" >SeniorCitizen</th>
#       <td id="T_bb90c_row2_col0" class="data row2 col0" >0.220173</td>
#       <td id="T_bb90c_row2_col1" class="data row2 col1" >0.103006</td>
#       <td id="T_bb90c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bb90c_row2_col3" class="data row2 col3" >0.150889</td>
#       <td id="T_bb90c_row2_col4" class="data row2 col4" >0.029381</td>
#       <td id="T_bb90c_row2_col5" class="data row2 col5" >-0.028418</td>
#       <td id="T_bb90c_row2_col6" class="data row2 col6" >0.016514</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row3" class="row_heading level0 row3" >HasEndDate</th>
#       <td id="T_bb90c_row3_col0" class="data row3 col0" >0.193356</td>
#       <td id="T_bb90c_row3_col1" class="data row3 col1" >-0.198324</td>
#       <td id="T_bb90c_row3_col2" class="data row3 col2" >0.150889</td>
#       <td id="T_bb90c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bb90c_row3_col4" class="data row3 col4" >0.181417</td>
#       <td id="T_bb90c_row3_col5" class="data row3 col5" >0.291621</td>
#       <td id="T_bb90c_row3_col6" class="data row3 col6" >-0.352673</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row4" class="row_heading level0 row4" >BeginMonth</th>
#       <td id="T_bb90c_row4_col0" class="data row4 col0" >-0.018072</td>
#       <td id="T_bb90c_row4_col1" class="data row4 col1" >-0.194289</td>
#       <td id="T_bb90c_row4_col2" class="data row4 col2" >0.029381</td>
#       <td id="T_bb90c_row4_col3" class="data row4 col3" >0.181417</td>
#       <td id="T_bb90c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bb90c_row4_col5" class="data row4 col5" >0.081542</td>
#       <td id="T_bb90c_row4_col6" class="data row4 col6" >-0.230318</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row5" class="row_heading level0 row5" >BeginYear</th>
#       <td id="T_bb90c_row5_col0" class="data row5 col0" >-0.264251</td>
#       <td id="T_bb90c_row5_col1" class="data row5 col1" >-0.819539</td>
#       <td id="T_bb90c_row5_col2" class="data row5 col2" >-0.028418</td>
#       <td id="T_bb90c_row5_col3" class="data row5 col3" >0.291621</td>
#       <td id="T_bb90c_row5_col4" class="data row5 col4" >0.081542</td>
#       <td id="T_bb90c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_bb90c_row5_col6" class="data row5 col6" >-0.987411</td>
#     </tr>
#     <tr>
#       <th id="T_bb90c_level0_row6" class="row_heading level0 row6" >UsingDays</th>
#       <td id="T_bb90c_row6_col0" class="data row6 col0" >0.247754</td>
#       <td id="T_bb90c_row6_col1" class="data row6 col1" >0.826109</td>
#       <td id="T_bb90c_row6_col2" class="data row6 col2" >0.016514</td>
#       <td id="T_bb90c_row6_col3" class="data row6 col3" >-0.352673</td>
#       <td id="T_bb90c_row6_col4" class="data row6 col4" >-0.230318</td>
#       <td id="T_bb90c_row6_col5" class="data row6 col5" >-0.987411</td>
#       <td id="T_bb90c_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Conclusions:</b>
#
# There is a high correlation between MonthlyCharges and TotalCharges, which is quite logical, as the more a customer pays for services, the higher their total payment amount will be.
#
# There is also a strong negative correlation between BeginYear and UsingDays, which is also logical, as the longer a customer uses the telecom services, the older their contract becomes.
#
# SeniorCitizen and HasEndDate have weak correlations with other features, which may mean that they do not strongly influence other variables.
#
# BeginMonth has weak correlations with other features, which may mean that the month the contract began does not have a significant impact on other variables.
#
# UsingDays has a strong correlation with TotalCharges, which may mean that the duration of using the telecom services can affect the total payment amount.

# %%
telecom['ClientLeft'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: ClientLeft, dtype: int64

# %%
plt.figsize=(5,5)
ax = telecom['ClientLeft'].value_counts().plot(kind='bar', color =['green', 'red'])
plt.title('Variable distribution ClientLeft')
plt.xlabel('ClientLeft')
plt.ylabel('Number of observations')
plt.xticks(rotation=0)
plt.legend(labels=['Remained',' Left'])
plt.show()

# %%
fig,axs = plt.subplots(ncols=2,figsize=(15,7))

sns.boxplot(x ='ClientLeft', y ='MonthlyCharges', data = telecom, ax=axs[0])
axs[0].set_title('Boxplot for current and churned customers MonthlyCharges', fontsize = 14)
sns.boxplot(x='ClientLeft', y='TotalCharges', data=telecom, ax=axs[1])
axs[1].set_title('Boxplot for current and churned customers TotalCharges', fontsize=14)
plt.tight_layout()
plt.show()

# %%
telecom1 = telecom[telecom['ClientLeft'] == 'No'][['MonthlyCharges', 'TotalCharges']].describe()
telecom2 = telecom[telecom['ClientLeft'] == 'Yes'][['MonthlyCharges', 'TotalCharges']].describe()

telecom3 = pd.concat([telecom1, telecom2], axis=1, keys=['Stay', 'Left'])
telecom3
# Out:
#                 Stay                        Left
#       MonthlyCharges TotalCharges MonthlyCharges TotalCharges
# count    5174.000000  5174.000000    1869.000000  1869.000000
# mean       61.265124  2549.911377      74.441332  1531.796143
# std        31.092648  2329.952148      24.666053  1890.823242
# min        18.250000     0.000000      18.850000    18.850000
# 25%        25.100000   572.899979      56.150000   134.500000
# 50%        64.425000  1679.525024      79.650000   703.549988
# 75%        88.400000  4262.849976      94.200000  2331.300049
# max       118.750000  8672.450195     118.350000  8684.799805

# %% [markdown]
# <b>
# As a result of the data analysis, we found that among customers who continue to use the company's services, the average monthly payment is $ 61.27 .
#
# Among customers who left the company, the average monthly payment is $ 74.44 . Additionally, we learned that the average total payment among customers who left the company is significantly lower than among customers who continue to use the company's services. These results can be useful for making decisions aimed at retaining customers.
# </b>

# %%
sns.displot(data=telecom, x="Type", hue='ClientLeft', multiple='dodge', stat='density', common_norm=False)
plt.title('Distribution of clients by payment')
plt.show()

# %% [markdown]
# <b>It is possible that customers who pay for telecommunication services on a monthly basis are more likely to terminate their contracts, despite the quality of the service provided. Perhaps this is due to the fact that customers who have paid for services for a year or two in advance do not want to lose the prepaid money and therefore continue to use the company's services, even if the quality of the service is unsatisfactory.</b>

# %%
sns.displot(data=telecom, x="PaperlessBilling", hue='ClientLeft', multiple='dodge', stat='density', common_norm=False)
plt.title('Distribution of clients by PaperlessBilling')
plt.show()

# %%
sns.catplot(data=telecom, y="PaymentMethod", hue='ClientLeft', kind='count', dodge=True)
plt.title('Distribution of clients by PaymentMethod')
plt.show()

# %% [markdown]
# The data analysis showed that the preferred payment option among customers is the use of electronic check. However, an interesting fact is that this group of customers is characterized by a high level of churn.

# %%
sns.displot(data=telecom, x="InternetService", hue='ClientLeft', multiple='dodge', stat='density', common_norm=False)
plt.title('Distribution of clients by InternetService')
plt.show()

# %%
fig,axes = plt.subplots(ncols=2,figsize=(12,7))

sns.countplot(data=telecom, x ='OnlineBackup', hue='ClientLeft', ax=axes[0])
axes[0].set_title('Distribution of clients by OnlineBackup')

sns.countplot(data=telecom, x ='OnlineSecurity', hue='ClientLeft', ax=axes[1])
axes[1].set_title('Distribution of clients by OnlineSecurity')
plt.show()

# %%
fig,axes = plt.subplots(ncols=2,figsize=(12,7))

sns.countplot(data=telecom, x ='DeviceProtection', hue='ClientLeft', ax=axes[0])
axes[0].set_title('Distribution of clients by DeviceProtection')

sns.countplot(data=telecom, x ='TechSupport', hue='ClientLeft', ax=axes[1])
axes[1].set_title('Distribution of clients by TechSupport')
plt.show()

# %%
fig,axes = plt.subplots(ncols=2,figsize=(12,7))

sns.countplot(data=telecom, x ='StreamingTV', hue='ClientLeft', ax=axes[0])
axes[0].set_title('Distribution of clients by StreamingTV')

sns.countplot(data=telecom, x ='StreamingMovies', hue='ClientLeft', ax=axes[1])
axes[1].set_title('Distribution of clients by StreamingMovies')
plt.show()

# %%
fig,axes = plt.subplots(ncols=2,figsize=(12,7))

sns.countplot(data=telecom, x ='SeniorCitizen', hue='ClientLeft', ax=axes[0])
axes[0].set_title('Distribution of clients by SeniorCitizen')

sns.countplot(data=telecom, x ='Partner', hue='ClientLeft', ax=axes[1])
axes[1].set_title('Distribution of clients by Partner')
plt.show()

# %% [markdown]
# There is a significantly smaller number of elderly customers compared to the younger generation. In addition, customers without a partner have a higher tendency to terminate their contract.

# %%
fig,axes = plt.subplots(ncols=2,figsize=(12,7))

sns.countplot(data=telecom, x ='Dependents', hue='ClientLeft', ax=axes[0])
axes[0].set_title('Distribution of clients by Dependents')

sns.countplot(data=telecom, x ='MultipleLines', hue='ClientLeft', ax=axes[1])
axes[1].set_title('Distribution of clients by MultipleLines')
plt.show()

# %% [markdown]
# sns.displot(data=telecom, x="BeginMonth", hue='ClientLeft', multiple='dodge', stat='density', common_norm=False)
# plt.title('Распределение  клиентов по BeginMonth')
# plt.show()

# %%
sns.displot(data=telecom, x="UsingDays", hue='ClientLeft', multiple='dodge', stat='density', common_norm=False)
plt.title('Distribution of clients byо UsingDays')
plt.show()

# %% [markdown]
# The chart demonstrates that in the first few months, many customers terminate their contracts, but over time, the number of such cases decreases. This means that over time, the ratio of the number of customers who continue to use the company's services to those who terminate their contracts increases.

# %%
telecom.drop(['Gender', 'BeginYear', 'BeginMonth','HasEndDate'], axis=1, inplace=True)
telecom.sample(5)
# Out:
#                       Type PaperlessBilling            PaymentMethod  \
# customerID
# 9851-QXEEQ  Month-to-month              Yes         Electronic check
# 3440-JPSCL  Month-to-month              Yes             Mailed check
# 3351-NGXYI  Month-to-month              Yes         Electronic check
# 7923-IYJWY        Two year              Yes  Credit card (automatic)
# 4074-SJFFA  Month-to-month              Yes             Mailed check
#
#             MonthlyCharges  TotalCharges InternetService OnlineSecurity  \
# customerID
# 9851-QXEEQ          104.70   4346.399902     Fiber optic             No
# 3440-JPSCL           99.95    547.650024     Fiber optic             No
# 3351-NGXYI           54.10    889.000000             DSL            Yes
# 7923-IYJWY          116.10   7839.850098     Fiber optic            Yes
# 4074-SJFFA           54.75     54.750000             DSL             No
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 9851-QXEEQ          Yes              Yes          No         Yes
# 3440-JPSCL           No              Yes         Yes         Yes
# 3351-NGXYI           No               No          No          No
# 7923-IYJWY          Yes              Yes         Yes         Yes
# 4074-SJFFA           No               No          No          No
#
#            StreamingMovies  SeniorCitizen Partner Dependents MultipleLines  \
# customerID
# 9851-QXEEQ             Yes              0      No         No           Yes
# 3440-JPSCL             Yes              0      No         No            No
# 3351-NGXYI              No              1      No         No           Yes
# 7923-IYJWY             Yes              1      No         No           Yes
# 4074-SJFFA             Yes              0      No         No            No
#
#            ClientLeft  UsingDays
# customerID
# 9851-QXEEQ        Yes       1248
# 3440-JPSCL        Yes        184
# 3351-NGXYI         No        488
# 7923-IYJWY         No       2041
# 4074-SJFFA        Yes         31

# %% [markdown]
# It is important to keep in mind that the influence of various factors on the target variable is a hypothesis, and methods for hypothesis testing should be used. However, this is a separate task.

# %% [markdown]
# ### Creating features for use in a machine learning model.

# %%
telecom.describe(include='all')
# Out:
#                   Type PaperlessBilling     PaymentMethod  MonthlyCharges  \
# count             7043             7043              7043     7043.000000
# unique               3                2                 4             NaN
# top     Month-to-month              Yes  Electronic check             NaN
# freq              3875             4171              2365             NaN
# mean               NaN              NaN               NaN       64.761692
# std                NaN              NaN               NaN       30.090047
# min                NaN              NaN               NaN       18.250000
# 25%                NaN              NaN               NaN       35.500000
# 50%                NaN              NaN               NaN       70.350000
# 75%                NaN              NaN               NaN       89.850000
# max                NaN              NaN               NaN      118.750000
#
#         TotalCharges InternetService OnlineSecurity OnlineBackup  \
# count    7043.000000            7043           7043         7043
# unique           NaN               3              2            2
# top              NaN     Fiber optic             No           No
# freq             NaN            3096           5024         4614
# mean     2279.734375             NaN            NaN          NaN
# std      2266.794434             NaN            NaN          NaN
# min         0.000000             NaN            NaN          NaN
# 25%       398.549988             NaN            NaN          NaN
# 50%      1394.550049             NaN            NaN          NaN
# 75%      3786.599976             NaN            NaN          NaN
# max      8684.799805             NaN            NaN          NaN
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7043        7043        7043            7043
# unique                2           2           2               2
# top                  No          No          No              No
# freq               4621        4999        4336            4311
# mean                NaN         NaN         NaN             NaN
# std                 NaN         NaN         NaN             NaN
# min                 NaN         NaN         NaN             NaN
# 25%                 NaN         NaN         NaN             NaN
# 50%                 NaN         NaN         NaN             NaN
# 75%                 NaN         NaN         NaN             NaN
# max                 NaN         NaN         NaN             NaN
#
#         SeniorCitizen Partner Dependents MultipleLines ClientLeft    UsingDays
# count     7043.000000    7043       7043          7043       7043  7043.000000
# unique            NaN       2          2             2          2          NaN
# top               NaN      No         No            No         No          NaN
# freq              NaN    3641       4933          4072       5174          NaN
# mean         0.162147     NaN        NaN           NaN        NaN   985.996166
# std          0.368612     NaN        NaN           NaN        NaN   747.587844
# min          0.000000     NaN        NaN           NaN        NaN     0.000000
# 25%          0.000000     NaN        NaN           NaN        NaN   273.000000
# 50%          0.000000     NaN        NaN           NaN        NaN   883.000000
# 75%          0.000000     NaN        NaN           NaN        NaN  1676.000000
# max          1.000000     NaN        NaN           NaN        NaN  2191.000000

# %%
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              7043 non-null   object
#  1   PaperlessBilling  7043 non-null   object
#  2   PaymentMethod     7043 non-null   object
#  3   MonthlyCharges    7043 non-null   float64
#  4   TotalCharges      7043 non-null   float32
#  5   InternetService   7043 non-null   object
#  6   OnlineSecurity    7043 non-null   object
#  7   OnlineBackup      7043 non-null   object
#  8   DeviceProtection  7043 non-null   object
#  9   TechSupport       7043 non-null   object
#  10  StreamingTV       7043 non-null   object
#  11  StreamingMovies   7043 non-null   object
#  12  SeniorCitizen     7043 non-null   int64
#  13  Partner           7043 non-null   object
#  14  Dependents        7043 non-null   object
#  15  MultipleLines     7043 non-null   object
#  16  ClientLeft        7043 non-null   object
#  17  UsingDays         7043 non-null   int64
# dtypes: float32(1), float64(1), int64(2), object(14)
# memory usage: 1.2+ MB

# %%
telecom['ClientLeft'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: ClientLeft, dtype: int64

# %% [markdown]
# We will convert the categorical feature 'ClientLeft' into a numerical format.

# %%
telecom['ClientLeft'] = telecom['ClientLeft'].replace({'No': 0, 'Yes': 1})
telecom
# Out:
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges InternetService OnlineSecurity  \
# customerID
# 7590-VHVEG           29.85     29.850000             DSL             No
# 5575-GNVDE           56.95   1889.500000             DSL            Yes
# 3668-QPYBK           53.85    108.150002             DSL            Yes
# 7795-CFOCW           42.30   1840.750000             DSL            Yes
# 9237-HQITU           70.70    151.649994     Fiber optic             No
# ...                    ...           ...             ...            ...
# 6840-RESVB           84.80   1990.500000             DSL            Yes
# 2234-XADUH          103.20   7362.899902     Fiber optic             No
# 4801-JZAZL           29.60    346.450012             DSL            Yes
# 8361-LTMKD           74.40    306.600006     Fiber optic             No
# 3186-AJIEK          105.65   6844.500000     Fiber optic            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 7590-VHVEG          Yes               No          No          No
# 5575-GNVDE           No              Yes          No          No
# 3668-QPYBK          Yes               No          No          No
# 7795-CFOCW           No              Yes         Yes          No
# 9237-HQITU           No               No          No          No
# ...                 ...              ...         ...         ...
# 6840-RESVB           No              Yes         Yes         Yes
# 2234-XADUH          Yes              Yes          No         Yes
# 4801-JZAZL           No               No          No          No
# 8361-LTMKD           No               No          No          No
# 3186-AJIEK           No              Yes         Yes         Yes
#
#            StreamingMovies  SeniorCitizen Partner Dependents MultipleLines  \
# customerID
# 7590-VHVEG              No              0     Yes         No            No
# 5575-GNVDE              No              0      No         No            No
# 3668-QPYBK              No              0      No         No            No
# 7795-CFOCW              No              0      No         No            No
# 9237-HQITU              No              0      No         No            No
# ...                    ...            ...     ...        ...           ...
# 6840-RESVB             Yes              0     Yes        Yes           Yes
# 2234-XADUH             Yes              0     Yes        Yes           Yes
# 4801-JZAZL              No              0     Yes        Yes            No
# 8361-LTMKD              No              1     Yes         No           Yes
# 3186-AJIEK             Yes              0      No         No            No
#
#             ClientLeft  UsingDays
# customerID
# 7590-VHVEG           0         31
# 5575-GNVDE           0       1036
# 3668-QPYBK           1         61
# 7795-CFOCW           0       1371
# 9237-HQITU           1         61
# ...                ...        ...
# 6840-RESVB           0        730
# 2234-XADUH           0       2191
# 4801-JZAZL           0        337
# 8361-LTMKD           1        123
# 3186-AJIEK           0       2010
#
# [7043 rows x 18 columns]

# %%
features = telecom.drop(['ClientLeft'],axis=1)
target = telecom['ClientLeft']

# %%
features.head()
# Out:
#                       Type PaperlessBilling              PaymentMethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
#
#             MonthlyCharges  TotalCharges InternetService OnlineSecurity  \
# customerID
# 7590-VHVEG           29.85     29.850000             DSL             No
# 5575-GNVDE           56.95   1889.500000             DSL            Yes
# 3668-QPYBK           53.85    108.150002             DSL            Yes
# 7795-CFOCW           42.30   1840.750000             DSL            Yes
# 9237-HQITU           70.70    151.649994     Fiber optic             No
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 7590-VHVEG          Yes               No          No          No
# 5575-GNVDE           No              Yes          No          No
# 3668-QPYBK          Yes               No          No          No
# 7795-CFOCW           No              Yes         Yes          No
# 9237-HQITU           No               No          No          No
#
#            StreamingMovies  SeniorCitizen Partner Dependents MultipleLines  \
# customerID
# 7590-VHVEG              No              0     Yes         No            No
# 5575-GNVDE              No              0      No         No            No
# 3668-QPYBK              No              0      No         No            No
# 7795-CFOCW              No              0      No         No            No
# 9237-HQITU              No              0      No         No            No
#
#             UsingDays
# customerID
# 7590-VHVEG         31
# 5575-GNVDE       1036
# 3668-QPYBK         61
# 7795-CFOCW       1371
# 9237-HQITU         61

# %%
target.head()
# Out:
# customerID
# 7590-VHVEG    0
# 5575-GNVDE    0
# 3668-QPYBK    1
# 7795-CFOCW    0
# 9237-HQITU    1
# Name: ClientLeft, dtype: int64

# %%
features_train, features_test, target_train, target_test = train_test_split(
                                                              features,target,
                                                            test_size=0.25,
                                                            random_state=130323,
                                                            )

# %%
print(f"Training set size: {features_train.shape}")
print(f"Test set size: {features_test.shape}")
# Out:
# Training set size: (5282, 17)
# Test set size: (1761, 17)

# %%
train_sample = features_train.shape[0]/features.shape[0]
test_sample = target_test.shape[0]/target.shape[0]
print(f"Training set size:: {train_sample*100:.2f}%")
print(f"Test set size: {test_sample*100:.2f}%")
# Out:
# Training set size:: 75.00%
# Test set size: 25.00%

# %%
features_x = features.copy()

features_train_x = features_train.copy()
features_test_x = features_test.copy()
target_train_x = target_train.copy()
target_test_x = target_test.copy()

# %%
print(features_train_x.shape)
print(features_test_x.shape)
# Out:
# (5282, 17)
# (1761, 17)

# %% [raw]
# print(features_train_x.columns)
# print(features_test_x.columns)

# %%
category_features_x = ['Type', 'PaperlessBilling','PaymentMethod', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingMovies','StreamingTV' , 'Partner', 'Dependents', 'MultipleLines']
encoder = OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False)
encoder.fit(features_train_x[category_features_x])

features_train_x[encoder.get_feature_names_out()] = encoder.transform(features_train_x[category_features_x])
features_train_x = features_train_x.drop(category_features_x, axis=1)

features_test_x[encoder.get_feature_names_out()] = encoder.transform(features_test_x[category_features_x])
features_test_x = features_test_x.drop(category_features_x, axis=1)

# %%
print(features_train_x.shape)
print(features_test_x.shape)
# Out:
# (5282, 21)
# (1761, 21)

# %%
numeric = ['MonthlyCharges', 'TotalCharges','UsingDays']

scaler = StandardScaler()
scaler.fit(features_train[numeric])

features_train_x[numeric] = scaler.transform(features_train[numeric])
features_test_x[numeric] = scaler.transform(features_test[numeric])

# %%
print(f"Size of the dataset features_train_x: {features_train_x.shape}")
print(f"Size of the dataset features_test_x: {features_test_x.shape}")
print(f"Size of the dataset target_train_x: {target_train_x.shape}")
print(f"Size of the dataset target_test_x: {target_test_x.shape}")
# Out:
# Size of the dataset features_train_x: (5282, 21)
# Size of the dataset features_test_x: (1761, 21)
# Size of the dataset target_train_x: (5282,)
# Size of the dataset target_test_x: (1761,)

# %% [markdown]
# ### Training and validation of the model.

# %% [markdown]
# #### Logistic regression

# %%
classifier_lr = LogisticRegression(random_state=12345)
pipe_lr = Pipeline([('clf', classifier_lr)])
params_lr = {'clf__solver': ['lbfgs', 'liblinear', 'sag'],
             'clf__C': [0.1, 0.5, 0.8, 1.0],
             'clf__max_iter': [1000],
             'clf__class_weight': ['balanced']
             }

grid_lr = GridSearchCV(pipe_lr,
                       scoring='roc_auc',
                       cv=5,
                       param_grid=params_lr,
                       n_jobs=-1,
                       verbose=2,
                       refit=True)
grid_lr.fit(features_train_x, target_train_x)
best_lr = grid_lr.best_estimator_
y_pred = grid_lr.predict(features_train_x)
accuracy_lr = cross_val_score(best_lr, features_train_x, target_train_x, scoring = 'roc_auc',  n_jobs = -1,cv=5).mean()
#accuracy_lr = cross_val_score(target_train_x, y_pred)
roc_auc_lr = grid_lr.best_score_

print('Accuracy:', accuracy_lr)
print("Best hyperparameters: ", grid_lr.best_params_)
print("ROC AUC: {:.2f}%".format(grid_lr.best_score_))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Accuracy: 0.844705280665974
# Best hyperparameters:  {'clf__C': 1.0, 'clf__class_weight': 'balanced', 'clf__max_iter': 1000, 'clf__solver': 'lbfgs'}
# ROC AUC: 0.84%

# %%
print('Accuracy:', accuracy_lr)
print()
print("Best hyperparameters: ", grid_lr.best_params_)
print()
print("ROC AUC: {:.2f}%".format(grid_lr.best_score_))
# Out:
# Accuracy: 0.844705280665974
#
# Best hyperparameters:  {'clf__C': 1.0, 'clf__class_weight': 'balanced', 'clf__max_iter': 1000, 'clf__solver': 'lbfgs'}
#
# ROC AUC: 0.84%

# %% [markdown]
# #### Random Forest

# %% [markdown]
# To use gradient boosting and RandomForestClassifier models, feature preparation is necessary.

# %%
features_rf = features.copy()

features_train_rf = features_train.copy()
features_test_rf = features_test.copy()
target_train_rf = target_train.copy()
target_test_rf = target_test.copy()

# %%
category_features_rf = ['Type', 'PaperlessBilling','PaymentMethod', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingMovies','StreamingTV' , 'Partner', 'Dependents', 'MultipleLines']
encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

# %%
columns = ['Type', 'PaperlessBilling','PaymentMethod', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingMovies','StreamingTV' , 'Partner', 'Dependents', 'MultipleLines']

features_encoder = pd.DataFrame(encoder.fit_transform(features_rf[columns]),
                            columns=features_rf[columns].columns,
                           index=features_rf[columns].index)
for column in columns:
    features_rf[column] = features_encoder[column]
features_rf

features_train_rf[category_features_rf] = encoder.transform(
    features_train_rf[category_features_rf])
features_test_rf[category_features_rf] = encoder.transform(
    features_test_rf[category_features_rf])

# %%
numeric_rf = ['MonthlyCharges', 'TotalCharges','UsingDays']

scaler = StandardScaler()
scaler.fit(features_train[numeric])

features_train_rf[numeric] = scaler.transform(features_train[numeric])
features_test_rf[numeric] = scaler.transform(features_test[numeric])

print('features_train:', features_train_rf.shape)
print('features_test:', features_test_rf.shape)
print('target_train:', target_train_rf.shape)
print('target_test:', target_test_rf.shape)
# Out:
# features_train: (5282, 17)
# features_test: (1761, 17)
# target_train: (5282,)
# target_test: (1761,)

# %% [markdown]
# <b>Random Forest Classifier</b>

# %%
rfc = RandomForestClassifier(class_weight='balanced',
                             bootstrap=True,
                             random_state=42)

rfc_params = {
     'n_estimators': [140],
     'max_depth': [30],
     'criterion': ['entropy'],
     'max_features': ['sqrt']

}

grid_search_rfc = GridSearchCV(rfc,
                                   rfc_params, 
                                   verbose=3,
                                   cv=10,
                                   n_jobs=-1,
                                  scoring='roc_auc')


grid_search_rfc.fit(features_train_rf, target_train_rf)
grid_search_rfc.best_score_
best_rf = grid_search_rfc.best_estimator_
y_pred_rf = grid_search_rfc.predict(features_train_rf)
accuracy_rf = cross_val_score(best_rf, features_train_rf, target_train_rf, scoring = 'roc_auc',cv=5).mean()
#accuracy_rf = accuracy_score(target_train_rf, y_pred_rf)
roc_auc_rf = grid_search_rfc.best_score_

print('Accuracy:', accuracy_rf)
print()
print("Best hyperparameters: ", grid_search_rfc.best_params_)
print()
print("ROC AUC: {:.2f}%".format(grid_search_rfc.best_score_))
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# Accuracy: 0.8433680016481244
#
# Best hyperparameters:  {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'n_estimators': 140}
#
# ROC AUC: 0.84%

# %% [markdown]
# #### CatBoost Model

# %%
catboost = CatBoostClassifier(loss_function='Logloss', random_seed=12345,silent=True)

catboost_params = {
    
    'iterations': [500, 1000],
    'learning_rate': [0.01, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg':[1],
}



grid_search_catboost = GridSearchCV(catboost,
                                   catboost_params, 
                                   verbose=3,
                                   cv=10,
                                   n_jobs=-1,
                                   scoring='roc_auc')


grid_search_catboost.fit(features_train_rf, target_train_rf)
grid_search_catboost.best_score_
best_cb = grid_search_catboost.best_estimator_
y_pred_cb = grid_search_catboost.predict(features_train_rf)
accuracy_cb = cross_val_score(best_cb, features_train_rf, target_train_rf, scoring = 'roc_auc',cv=5).mean()
#accuracy_cb = accuracy_score(target_train_rf, y_pred_rf)
roc_auc_cb = grid_search_catboost.best_score_

print('Accuracy:', accuracy_cb)
print("Best hyperparameters: ", grid_search_catboost.best_params_)
print("ROC AUC: {:.2f}%".format(grid_search_catboost.best_score_))
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# Accuracy: 0.9138178687851131
# Best hyperparameters:  {'depth': 4, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.1}
# ROC AUC: 0.92%

# %%
print('Accuracy:', accuracy_cb)
print()
print("Best hyperparameters: ", grid_search_catboost.best_params_)
print()
print("ROC AUC: {:.2f}%".format(grid_search_catboost.best_score_))
# Out:
# Accuracy: 0.9138178687851131
#
# Best hyperparameters:  {'depth': 4, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.1}
#
# ROC AUC: 0.92%

# %% [markdown]
# #### XGBoostClassifier

# %%
classifier_xgb = XGBClassifier(random_state=12345)


params_xgb = {    
    'max_depth': range(1, 6),
    'learning_rate': [0.1, 0.01],
    'n_estimators': range(50, 100, 200),
    'booster': ['gbtree', 'gblinear'],       
} 
 
grid_xgb = GridSearchCV(classifier_xgb,
                       scoring='roc_auc',
                       cv=5,
                       param_grid=params_xgb,
                       n_jobs=-1,
                       refit=True
)


grid_xgb.fit(features_train_rf, target_train_rf)
grid_xgb.best_score_
best_xgb = grid_xgb.best_estimator_
y_pred_xgb = grid_xgb.predict(features_train_rf)
roc_auc_xgb = roc_auc_score(target_train_rf, y_pred_xgb)
accuracy_xgb = cross_val_score(best_xgb, features_train_rf, target_train_rf, scoring = 'roc_auc',cv=5).mean()
#accuracy_xgb = accuracy_score(target_train_rf, y_pred_xgb)
print('Accuracy:', accuracy_xgb)
print("Best hyperparameters: ", grid_xgb.best_params_)
print("ROC AUC: {:.2f}%".format(grid_xgb.best_score_))
# Out:
# Accuracy: 0.8659476204670666
# Best hyperparameters:  {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
# ROC AUC: 0.87%

# %%
print('Accuracy:', accuracy_xgb)
print()
print("Best hyperparameters: ", grid_xgb.best_params_)
print()
print("ROC AUC: {:.2f}%".format(grid_xgb.best_score_))
# Out:
# Accuracy: 0.8659476204670666
#
# Best hyperparameters:  {'booster': 'gbtree', 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
#
# ROC AUC: 0.87%

# %%
#Combine the obtained data into one table.
results = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest Classifier',
               'CatBoost Model', 'XGBoost Classifier'],
    'ROC_AUC модели': [roc_auc_lr, roc_auc_rf, roc_auc_cb, roc_auc_xgb],
    'Accuracy': [accuracy_lr, accuracy_rf, accuracy_cb, accuracy_xgb]
})


results.set_index('Model', inplace=True)
results
# Out:
#                           ROC_AUC модели  Accuracy
# Model
# Logistic Regression             0.844705  0.844705
# Random Forest Classifier        0.842395  0.843368
# CatBoost Model                  0.921422  0.913818
# XGBoost Classifier              0.768437  0.865948

# %% [markdown]
# <b>Based on the quality metrics of the models, the best model is the CatBoost Model with an ROC AUC of 0.921 and an Accuracy of 0.914. It demonstrates the highest quality and can be used to predict customer churn in this business.</b>

# %% [markdown]
# ### Evaluation of model performance on the test set.

# %% [markdown]
# #### Let's evaluate the performance of the CatBoost Model on the test set.

# %%
best_parm_cb = grid_search_catboost.best_params_
best_cb = grid_search_catboost.best_estimator_
#y_pred_cb_test = grid_search_catboost.predict_proba(features_test_rf)
y_pred_cb_test = grid_search_catboost.predict_proba(features_test_rf)[:, 1]
accuracy_cb_test = cross_val_score(best_cb, features_train_rf, target_train_rf, scoring = 'roc_auc',cv=5).mean()
#roc_auc_cb_test = roc_auc_score(target_test_rf, y_pred_cb_test[:, 1])
roc_auc_cb_test = roc_auc_score(target_test_rf, y_pred_cb_test)
print('Accuracy on test set for CatBoost Model:', accuracy_cb_test)
print()
print("Best hyperparameters for CatBoost Model: ", grid_search_catboost.best_params_)
print()
print("ROC AUC on test set for CatBoost Model:",roc_auc_cb_test)
# Out:
# Accuracy on test set for CatBoost Model: 0.9138178687851131
#
# Best hyperparameters for CatBoost Model:  {'depth': 4, 'iterations': 1000, 'l2_leaf_reg': 1, 'learning_rate': 0.1}
#
# ROC AUC on test set for CatBoost Model: 0.9335795475035981

# %% [markdown]
# <b>The CatBoost Model demonstrated good accuracy on the test set, reaching 0.913.
#
# The ROC AUC on the test set for the CatBoost model is 0.9336, indicating a good quality of the model.</b>

# %% [markdown]
# #### Let's plot the ROC curve.

# %%
#fpr, tpr, thresholds = roc_curve(target_test_rf, y_pred_cb_test[:, 1])
fpr, tpr, thresholds = roc_curve(target_test_rf, y_pred_cb_test)
plt.figure(figsize=(12, 10))
plt.plot(fpr, tpr)
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve plot')

plt.plot([0, 1], [0, 1], linestyle='--')
plt.show()

# %%
importances = grid_search_catboost.best_estimator_.feature_importances_


feature_importances = pd.DataFrame({'feature': features_train_rf.columns, 'importance': importances})
feature_importances = feature_importances.sort_values('importance', ascending=False)


plt.figure(figsize=(12, 8))
sns.barplot(x='importance', y='feature', data=feature_importances, palette='viridis')
plt.title('Feature importance analysis for CatBoost Model')
plt.show()

# %% [markdown]
# <b>According to the feature importance analysis for the CatBoost model, the most significant features that strongly affect the result are 'UsingDays', 'TotalCharges', and 'MonthlyCharges'.</b>

# %%
#y_pred_cb_test_binary = np.round(y_pred_cb_test[:, 1]).astype(int)
y_pred_cb_test_binary = np.round(y_pred_cb_test).astype(int)
report = classification_report(target_test_rf, y_pred_cb_test_binary, output_dict=True)
report_end = pd.DataFrame(report).transpose()
report_end
# Out:
#               precision    recall  f1-score      support
# 0              0.899563  0.960373  0.928974  1287.000000
# 1              0.868217  0.708861  0.780488   474.000000
# accuracy       0.892675  0.892675  0.892675     0.892675
# macro avg      0.883890  0.834617  0.854731  1761.000000
# weighted avg   0.891126  0.892675  0.889007  1761.000000

# %% [markdown]
# <b>Based on precision, recall, and f1-score metrics, it can be concluded that the CatBoost model accurately predicts the "0" class, as well as has good generalization ability (as evidenced by the accuracy metric value of 0.893 on the test set). However, the model less accurately identifies the "1" class.</b>
